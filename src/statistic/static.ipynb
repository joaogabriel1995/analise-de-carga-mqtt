# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv("../../data/device-1-sizepayload-6-msg-200-pilot/d059ea6f-4c34-4199-8c44-8d2c07810193.csv")

# %%
df["rtt"] =df["receive_time"] - df["send_time"]

# %%
df
# Out:
#                 type  qos                                        topic  \
# 0    Round Trip Time    0  device/d059ea6f-4c34-4199-8c44-8d2c07810193
# 1    Round Trip Time    0  device/d059ea6f-4c34-4199-8c44-8d2c07810193
# 2    Round Trip Time    0  device/d059ea6f-4c34-4199-8c44-8d2c07810193
# 3    Round Trip Time    0  device/d059ea6f-4c34-4199-8c44-8d2c07810193
# 4    Round Trip Time    0  device/d059ea6f-4c34-4199-8c44-8d2c07810193
# ..               ...  ...                                          ...
# 195  Round Trip Time    0  device/d059ea6f-4c34-4199-8c44-8d2c07810193
# 196  Round Trip Time    0  device/d059ea6f-4c34-4199-8c44-8d2c07810193
# 197  Round Trip Time    0  device/d059ea6f-4c34-4199-8c44-8d2c07810193
# 198  Round Trip Time    0  device/d059ea6f-4c34-4199-8c44-8d2c07810193
# 199  Round Trip Time    0  device/d059ea6f-4c34-4199-8c44-8d2c07810193
#
#      timeout                                  name  message_count  size  \
# ...
